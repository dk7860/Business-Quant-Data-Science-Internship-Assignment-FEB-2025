# %% [markdown]
# <h1 style="text-align: center; color: Blue;">Business Quant-Data Science Internship Assignment (FEB-2025)</h1>

# %% [markdown]
# ![Business%20Quant-2.jpeg](attachment:Business%20Quant-2.jpeg)

# %% [markdown]
# <h3 style="color:Black">Step-1:Extract the data from Raw  files using HTML codes </h3>

# %%
html_content="""<!DOCTYPE html>
<html>
<body>

<table border="2">
    <tr>
        <th>File Name</th>
        <th>Label</th>
        <th>Table Title</th>
        <th>Column Header</th>
        <th>Value</th>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Revenues(Millions($))</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td></td>
    </tr>
        <tr>
        <td>Table 9</td>
        <td>Revenue(Millions($))</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td></td>
    <tr>
        <td>Table 9</td>
        <td>Revenues(Millions($))</td>
        <td>Three months ended March 31</td>
        <td>%ChangeFav (Unfav)</td>
        <td></td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Revenues(Millions($))</td>
        <td>Three months ended March 31</td>
        <td>Change atconstantcurrencyFav (Unfav)</td>
        <td></td>
    </tr>
        
        
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>756</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>661</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>14%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>14%</td>
    </tr>



    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>406</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>368</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>10%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>10%</td>
    </tr>


 <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>426</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>429</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>1%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>1%</td>
    </tr>


 <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>195</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>126</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>55%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>55%</td>
    </tr>

 <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>604</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>713</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>15%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>15%</td>
    </tr>

 
 <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>1056</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>968</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>9%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>9%</td>
    </tr>
<tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>165</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>158</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>4%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>4%</td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Total freight revenues</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>3608</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total freight revenues</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>3423</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total freight revenues</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>5%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total freight revenues</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>5%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Other revenues</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>100</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Other revenues</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>112</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Other revenues</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>11%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Other revenues</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>11%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Total revenues</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>3708</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total revenues</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>3535</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total revenues</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>5%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total revenues</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>5%</td>
    </tr>
    
    
    <tr>
        <td>Table 9</td>
        <td>Revenue ton miles (RTMs) (Millions($))</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Revenue ton miles (RTMs) (Millions($))</td>
        <td> Three months ended March 31</td>
        <td>2021</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Revenue ton miles (RTMs) (Millions($))</td>
        <td>Three months ended March 31</td>
        <td>%ChangeFav (Unfav)</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Revenue ton miles (RTMs) (Millions($))</td>
        <td>Three months ended March 31</td>
        <td>%Change at constant currency Fav (Unfav)</td>
        <td></td>
    </tr>
    
    
    
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>11559</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>10732</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>8%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>8%</td>
    </tr>



    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>6263</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>6293</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td></td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td></td>
    </tr>


    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>5819</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>6670</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>13%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% Change at constant currency Fav (Unfav)</td>
        <td>13%</td>
    </tr>


    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>5368</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>4026</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>33%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>33%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>13,351</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>17,841</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>25%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>25%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>13556</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>15233</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>11%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>11%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>638</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>659</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>3%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>3%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Total RTMs</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>56,554</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total RTMs</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>61,454</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total RTMs</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>8%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total RTMs</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>8%</td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Freight revenue / RTM (cents) </td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Freight revenue / RTM (cents) </td>
        <td> Three months ended March 31</td>
        <td>2021</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Freight revenue / RTM (cents) </td>
        <td>Three months ended March 31</td>
        <td>%ChangeFav (Unfav)</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Freight revenue / RTM (cents) </td>
        <td>Three months ended March 31</td>
        <td>%Change at constant currency Fav (Unfav)</td>
        <td></td>
    </tr>
    
    
    
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>6.54</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>6.16</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>6%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>6%</td>
    </tr>



    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>6.48</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>5.85</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>11%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>11%</td>
    </tr>


    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>7.32</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>6.43</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>14%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% Change at constant currency Fav (Unfav)</td>
        <td>14%</td>
    </tr>


    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>3.63</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>3.13</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>16%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>16%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>4.52</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>4.00</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>13%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>13%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>7.79</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>6.35</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>23%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>23%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>25.86</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>23.98</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>8%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>8%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Total freight revenue / RTM</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>6.38</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total freight revenue / RTM</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>5.57</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total freight revenue / RTM</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>15%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total freight revenue / RTM</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>15%</td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Carloads (thousands)</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Carloads (thousands) </td>
        <td> Three months ended March 31</td>
        <td>2021</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Carloads (thousands)</td>
        <td>Three months ended March 31</td>
        <td>%ChangeFav (Unfav)</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Carloads (thousands)</td>
        <td>Three months ended March 31</td>
        <td>%Change at constant currency Fav (Unfav)</td>
        <td></td>
    </tr>
    
    
    
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>159</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>150</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>6%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>6%</td>
    </tr>



    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>209</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>223</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>6%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>6%</td>
    </tr>


    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>78</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>86</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>9%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% Change at constant currency Fav (Unfav)</td>
        <td>9%</td>
    </tr>


    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>118</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>69</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>71%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>71%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>145</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>176</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>18%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>18%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>589</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>676</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>13%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>13%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>48</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>51</td>
        <td>23.98</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>6%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>6%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Total carloads</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>1346</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total carloads</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>1431</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total carloads</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>6%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total carloads</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>6%</td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Freight revenue / carload ($)</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Freight revenue / carload ($)</td>
        <td> Three months ended March 31</td>
        <td>2021</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Freight revenue / carload ($)</td>
        <td>Three months ended March 31</td>
        <td>%ChangeFav (Unfav)</td>
        <td></td>
    </tr>
    
    <tr>
        <td>Table 9</td>
        <td>Freight revenue / carload ($)</td>
        <td>Three months ended March 31</td>
        <td>%Change at constant currency Fav (Unfav)</td>
        <td></td>
    </tr>
    
    
    
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>4755</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>4407</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>8%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Petroleum and chemicals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>8%</td>
    </tr>



    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>1943</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>1650</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>18%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Metals and minerals</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>18%</td>
    </tr>


    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>5462</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>4988</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>10%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Forest products</td>
        <td>Three months ended March 31</td>
        <td>% Change at constant currency Fav (Unfav)</td>
        <td>10%</td>
    </tr>


    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>1653</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>1826</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>9%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Coal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>9%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>4166</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>4051</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>3%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Grain and fertilizers</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>3%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>1793</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>1432</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>25%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Intermodal</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>25%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>3438</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>51</td>
        <td>3098</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>11%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Automotive</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>11%</td>
    </tr>

    <tr>
        <td>Table 9</td>
        <td>Total freight revenue / carload</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>2681</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total freight revenue / carload</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>2392</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total freight revenue / carload</td>
        <td>Three months ended March 31</td>
        <td>% ChangeFav (Unfav)</td>
        <td>12%</td>
    </tr>
    <tr>
        <td>Table 9</td>
        <td>Total freight revenue / carload</td>
        <td>Three months ended March 31</td>
        <td>% Change atconstantcurrencyFav (Unfav)</td>
        <td>12%</td>
    </tr>
    <tr>
        <td>Table 12</td>
        <td>Net cash(in Millions($)) provided by operating activities</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>570</td>
    </tr>
    
    <tr>
        <td>Table 12</td>
        <td>Net cash(in Millions($)) provided by operating activities</td>
        <td> Three months ended March 31</td>
        <td>2021</td>
        <td>952</td>
        
       
    <tr>
        <td>Table 12</td>
        <td>Net cash (in Millions($)) used in investing activities</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>101</td>
    </tr>
    
    <tr>
        <td>Table 12</td>
        <td>Net cash (in Millions($)) used in investing activities</td>
        <td> Three months ended March 31</td>
        <td>2021</td>
        <td>413</td>
        
        
    <tr>
        <td>Table 12</td>
        <td>Net cash (in Millions($)) provided before financing activities</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>469</td>
    </tr>
    
    <tr>
        <td>Table 12</td>
        <td>Net cash (in Millions($)) provided before financing activities</td>
        <td> Three months ended March 31</td>
        <td>2021</td>
        <td>539</td>
        
        
    <tr>
        <td>Table 12</td>
        <td>Adjustment: Cash income (in Millions($)) taxes 
            for merger transaction-related payments and cash receipts</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>102</td>
    </tr>
    
    <tr>
        <td>Table 12</td>
        <td>Adjustment: Cash income (in Millions($)) taxes 
            for merger transaction-related payments and cash receipts</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td></td>
        
        
    <tr>
        <td>Table 12</td>
        <td>Free cash flow(in Millions($))</td>
        <td>Three months ended March 31</td>
        <td>2022</td>
        <td>571</td>
    </tr>
    
    <tr>
        <td>Table 12</td>
        <td>Free cash flow(in Millions($))</td>
        <td>Three months ended March 31</td>
        <td>2021</td>
        <td>539</td>
          
    <tr>
        <td>Table 62</td>
        <td>Debt obligations (in Millions($))</td>
        <td></td>
        <td>Total</td>
        <td>13,380</td>
    </tr>

    <tr>
        <td>Table 62</td>
        <td>Debt obligations (in Millions($))</td>
        <td></td>
        <td>2022</td>
        <td>1495</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Debt obligations (in Millions($))</td>
        <td></td>
        <td>2023</td>
        <td>220</td>
        
       
    <tr>
        <td>Table 62</td>
        <td>Debt obligations (in Millions($))</td>
        <td></td>
        <td>2024</td>
        <td>471</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Debt obligations (in Millions($))</td>
        <td></td>
        <td>2025</td>
        <td>384</td>
        
        
    <tr>
        <td>Table 62</td>
        <td>Debt obligations (in Millions($))</td>
        <td></td>
        <td>2026</td>
        <td>661</td>
    </tr>
        
    <tr>
        <td>Table 62</td>
        <td>Debt obligations (in Millions($))</td>
        <td></td>
        <td>2027 & Thereafter</td>
        <td>10,149</td>
    </tr>
 
 
 
    <tr>
        <td>Table 62</td>
        <td>Interest on debt obligations (in Millions($))</td>
        <td></td>
        <td>Total</td>
        <td>9,056</td>
    </tr>

    <tr>
        <td>Table 62</td>
        <td>Interest on debt obligations (in Millions($))</td>
        <td></td>
        <td>2022</td>
        <td>328</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Interest on debt obligations (in Millions($))</td>
        <td></td>
        <td>2023</td>
        <td>483</td>
        
       
    <tr>
        <td>Table 62</td>
        <td>Interest on debt obligations (in Millions($))</td>
        <td></td>
        <td>2024</td>
        <td>476</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Interest on debt obligations (in Millions($))</td>
        <td></td>
        <td>2025</td>
        <td>462</td>
        
        
    <tr>
        <td>Table 62</td>
        <td>Interest on debt obligations (in Millions($))</td>
        <td></td>
        <td>2026</td>
        <td>443</td>
    </tr>
        
    <tr>
        <td>Table 62</td>
        <td>Interest on debt obligations (in Millions($))</td>
        <td></td>
        <td>2027 & Thereafter</td>
        <td>6,864</td>
    </tr>
 
  
  
  
    <tr>
        <td>Table 62</td>
        <td>Finance lease obligations</td>
        <td></td>
        <td>Total</td>
        <td>3</td>
    </tr>

    <tr>
        <td>Table 62</td>
        <td>Finance lease obligations</td>
        <td></td>
        <td>2022</td>
        <td>1</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Finance lease obligations</td>
        <td></td>
        <td>2023</td>
        <td>0</td>
        
       
    <tr>
        <td>Table 62</td>
        <td>Finance lease obligations</td>
        <td></td>
        <td>2024</td>
        <td>0</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Finance lease obligations</td>
        <td></td>
        <td>2025</td>
        <td>0</td>
        
        
    <tr>
        <td>Table 62</td>
        <td>Finance lease obligations</td>
        <td></td>
        <td>2026</td>
        <td>2</td>
    </tr>
        
    <tr>
        <td>Table 62</td>
        <td>Finance lease obligations</td>
        <td></td>
        <td>2027 & Thereafter</td>
        <td>0</td>
    </tr>
 

    <tr>
        <td>Table 62</td>
        <td>Operating lease obligations(in Millions($))</td>
        <td></td>
        <td>Total</td>
        <td>468</td>
    </tr>

    <tr>
        <td>Table 62</td>
        <td>Operating lease obligations(in Millions($))</td>
        <td></td>
        <td>2022</td>
        <td>91</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Operating lease obligations(in Millions($))</td>
        <td></td>
        <td>2023</td>
        <td>100</td>
        
       
    <tr>
        <td>Table 62</td>
        <td>Operating lease obligations(in Millions($))</td>
        <td></td>
        <td>2024</td>
        <td>73</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Operating lease obligations(in Millions($))</td>
        <td></td>
        <td>2025</td>
        <td>60</td>
        
        
    <tr>
        <td>Table 62</td>
        <td>Operating lease obligations(in Millions($))</td>
        <td></td>
        <td>2026</td>
        <td>40</td>
    </tr>
        
    <tr>
        <td>Table 62</td>
        <td>Operating lease obligations(in Millions($))</td>
        <td></td>
        <td>2027 & Thereafter</td>
        <td>104</td>
    </tr>
 
 
    <tr>
        <td>Table 62</td>
        <td>Purchase obligations(in Millions($))</td>
        <td></td>
        <td>Total</td>
        <td>1,654</td>
    </tr>

    <tr>
        <td>Table 62</td>
        <td>Purchase obligations(in Millions($))</td>
        <td></td>
        <td>2022</td>
        <td>1,178</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Purchase obligations(in Millions($))</td>
        <td></td>
        <td>2023</td>
        <td>253</td>
        
       
    <tr>
        <td>Table 62</td>
        <td>Purchase obligations(in Millions($))</td>
        <td></td>
        <td>2024</td>
        <td>111</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Purchase obligations(in Millions($))</td>
        <td></td>
        <td>2025</td>
        <td>106</td>
        
        
    <tr>
        <td>Table 62</td>
        <td>Purchase obligations(in Millions($))</td>
        <td></td>
        <td>2026</td>
        <td>1</td>
    </tr>
        
    <tr>
        <td>Table 62</td>
        <td>Purchase obligations(in Millions($))</td>
        <td></td>
        <td>2027 & Thereafter</td>
        <td>5</td>
    </tr>
 
 
 
    <tr>
        <td>Table 62</td>
        <td>Other long-term liabilities(in Millions($))</td>
        <td></td>
        <td>Total</td>
        <td>657</td>
    </tr>

    <tr>
        <td>Table 62</td>
        <td>Other long-term liabilities (in Millions($))</td>
        <td></td>
        <td>2022</td>
        <td>74</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Other long-term liabilities (in Millions($))</td>
        <td></td>
        <td>2023</td>
        <td>51</td>
        
       
    <tr>
        <td>Table 62</td>
        <td>Other long-term liabilities(in Millions($))</td>
        <td></td>
        <td>2024</td>
        <td>43</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Other long-term liabilities(in Millions($))</td>
        <td></td>
        <td>2025</td>
        <td>41</td>
        
        
    <tr>
        <td>Table 62</td>
        <td>Other long-term liabilities(in Millions($))</td>
        <td></td>
        <td>2026</td>
        <td>33</td>
    </tr>
        
    <tr>
        <td>Table 62</td>
        <td>Other long-term liabilities(in Millions($))</td>
        <td></td>
        <td>2027 & Thereafter</td>
        <td>415</td>
    </tr>
 
     <tr>
        <td>Table 62</td>
        <td>Total contractual obligations(in Millions($))</td>
        <td></td>
        <td>Total</td>
        <td>25,218</td>
    </tr>

    <tr>
        <td>Table 62</td>
        <td>Total contractual obligations(in Millions($))</td>
        <td></td>
        <td>2022</td>
        <td>3,167</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Total contractual obligations (in Millions($))</td>
        <td></td>
        <td>2023</td>
        <td>1107</td>
        
       
    <tr>
        <td>Table 62</td>
        <td>Total contractual obligations(in Millions($))</td>
        <td></td>
        <td>2024</td>
        <td>1,174</td>
    </tr>
    
    <tr>
        <td>Table 62</td>
        <td>Total contractual obligations(in Millions($))</td>
        <td></td>
        <td>2025</td>
        <td>1,053</td>
        
        
    <tr>
        <td>Table 62</td>
        <td>Total contractual obligations(in Millions($))</td>
        <td></td>
        <td>2026</td>
        <td>1,180</td>
    </tr>
        
    <tr>
        <td>Table 62</td>
        <td>Total contractual obligations(in Millions($))</td>
        <td></td>
        <td>2027 & Thereafter</td>
        <td>17,537</td>
    </tr>
 
</table>

</body>
</html>"""
print(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <table border="2">
#     <tr>
#         <th>File Name</th>
#         <th>Label</th>
#         <th>Table Title</th>
#         <th>Column Header</th>
#         <th>Value</th>
#     </tr>
#     <tr>
#         <td>Table 9</td>
#         <td>Revenues(Millions($))</td>
#         <td>Three months ended March 31</td>
#         <td>2022</td>
#         <td></td>
#     </tr>
#         <tr>
#         <td>Table 9</td>
#         <td>Revenue(Millions($))</td>
#         <td>Three months ended March 31</td>
#         <td>2021</td>
#         <td></td>
#     <tr>
#         <td>Table 9</td>
#         <td>Revenues(Millions($))</td>
#         <td>Three months ended March 31</td>
#         <td>%ChangeFav (Unfav)</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Table 9</td>
#         <td>Revenues(Millions($))</td>
#         <td>Three months ended March 31</td>
#         <td>Change atconstantcurrencyFav (Unfav)</td>
#         <td></td>
#     </tr>
#
#
# ...

# %% [markdown]
# <h3 style="color:Black">Step-2: After Extraction of required data,save the file in HTML format </h3>

# %%
file_name = "Business_Quant.html"

# Write the HTML content to the file
with open(file_name, "w") as file:
    file.write(html_content)

print(f"HTML file '{file_name}' has been saved.")
# Out:
# HTML file 'Business_Quant.html' has been saved.

# %% [markdown]
# <h3 style="color:Black">Step-3 :Saved HTML file then used to read informative data by lxml parser and after parsing the data is saved in a dataframe</h3>

# %%
import pandas as pd
# Approach 4: Using lxml parser with read_html()
def read_html_with_lxml(file_path):
    # Read HTML file into DataFrame using read_html() with 'lxml' parser
    df = pd.read_html(file_path, flavor='lxml')[0]
    return df

# File path
html_file_path = r'C:\Users\Sun\Desktop\Business Quant Dataset - Html Tables\Final Output(HTML,EXcel & ipynb)\Business_Quant.html'

# Read HTML file using lxml parser with read_html()
df = read_html_with_lxml(html_file_path)

# Display DataFrame
print(df)
# Out:
#     File Name                                           Label  \
# 0     Table 9                           Revenues(Millions($))
# 1     Table 9                            Revenue(Millions($))
# 2     Table 9                           Revenues(Millions($))
# 3     Table 9                           Revenues(Millions($))
# 4     Table 9                         Petroleum and chemicals
# ..        ...                                             ...
# 242  Table 62  Total contractual obligations (in Millions($))
# 243  Table 62   Total contractual obligations(in Millions($))
# 244  Table 62   Total contractual obligations(in Millions($))
# 245  Table 62   Total contractual obligations(in Millions($))
# 246  Table 62   Total contractual obligations(in Millions($))
#
#                      Table Title                         Column Header  Value
# 0    Three months ended March 31                                  2022    NaN
# ...

# %%
df.to_excel('Final_output.xlsx', index=True)
df
# Out:
#     File Name                                           Label  \
# 0     Table 9                           Revenues(Millions($))
# 1     Table 9                            Revenue(Millions($))
# 2     Table 9                           Revenues(Millions($))
# 3     Table 9                           Revenues(Millions($))
# 4     Table 9                         Petroleum and chemicals
# ..        ...                                             ...
# 242  Table 62  Total contractual obligations (in Millions($))
# 243  Table 62   Total contractual obligations(in Millions($))
# 244  Table 62   Total contractual obligations(in Millions($))
# 245  Table 62   Total contractual obligations(in Millions($))
# 246  Table 62   Total contractual obligations(in Millions($))
#
#                      Table Title                         Column Header  Value
# 0    Three months ended March 31                                  2022    NaN
# ...

# %% [markdown]
# <h1 style="text-align: center; color: Blue;">THE END</h1>
